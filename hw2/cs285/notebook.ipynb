# %%
# !python cs285/scripts/run_hw2.py --env_name CartPole-v0 -n 100 -b 1000 --exp_name cartpole
# Out:
# ^C
# c:\Users\Matthias\anaconda3\envs\cs285\lib\site-packages\gym\envs\registration.py:593: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(
# c:\Users\Matthias\anaconda3\envs\cs285\lib\site-packages\gym\core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# c:\Users\Matthias\anaconda3\envs\cs285\lib\site-packages\gym\wrappers\step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# c:\Users\Matthias\anaconda3\envs\cs285\lib\site-packages\gym\utils\passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# c:\Users\Matthias\anaconda3\envs\cs285\lib\site-packages\tensorboardX\summary.py:153: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   scalar = float(scalar)
# ########################
# logging outputs to  C:\Users\Matthias\Documents\GitHub\homework_fall2023\hw2\cs285\scripts\../../data\q2_pg_cartpole_CartPole-v0_08-02-2024_22-19-50
# ########################
# Using CPU.
#
# ********** Iteration 0 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 28.200000762939453
# Eval_StdReturn : 8.810600280761719
# Eval_MaxReturn : 41.0
# Eval_MinReturn : 12.0
# Eval_AverageEpLen : 28.2
# Train_AverageReturn : 24.023256301879883
# Train_StdReturn : 12.848832130432129
# Train_MaxReturn : 75.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 24.023255813953487
# Actor Loss : 21987.05078125
# Train_EnvstepsSoFar : 1033
# TimeSinceStart : 0.9347114562988281
# Initial_DataCollection_AverageReturn : 24.023256301879883
# Done logging...
#
#
#
# ********** Iteration 1 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 26.6875
# Eval_StdReturn : 9.156410217285156
# Eval_MaxReturn : 47.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 26.6875
# Train_AverageReturn : 32.709678649902344
# Train_StdReturn : 19.131452560424805
# Train_MaxReturn : 86.0
# Train_MinReturn : 12.0
# Train_AverageEpLen : 32.70967741935484
# Actor Loss : 29668.4609375
# Train_EnvstepsSoFar : 2047
# TimeSinceStart : 1.5968577861785889
# Done logging...
#
#
#
# ********** Iteration 2 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 60.42856979370117
# Eval_StdReturn : 22.487184524536133
# Eval_MaxReturn : 92.0
# Eval_MinReturn : 26.0
# Eval_AverageEpLen : 60.42857142857143
# Train_AverageReturn : 43.4782600402832
# Train_StdReturn : 25.734209060668945
# Train_MaxReturn : 116.0
# Train_MinReturn : 14.0
# Train_AverageEpLen : 43.47826086956522
# Actor Loss : 38363.78125
# Train_EnvstepsSoFar : 3047
# TimeSinceStart : 2.2464287281036377
# Done logging...
#
#
#
# ********** Iteration 3 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 31.153846740722656
# Eval_StdReturn : 8.094120025634766
# Eval_MaxReturn : 43.0
# Eval_MinReturn : 19.0
# Eval_AverageEpLen : 31.153846153846153
# Train_AverageReturn : 47.66666793823242
# Train_StdReturn : 29.373348236083984
# Train_MaxReturn : 135.0
# Train_MinReturn : 17.0
# Train_AverageEpLen : 47.666666666666664
# Actor Loss : 41424.6171875
# Train_EnvstepsSoFar : 4048
# TimeSinceStart : 2.7547712326049805
# Done logging...
#
#
#
# ********** Iteration 4 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 34.08333206176758
# Eval_StdReturn : 13.810975074768066
# Eval_MaxReturn : 64.0
# Eval_MinReturn : 12.0
# Eval_AverageEpLen : 34.083333333333336
# Train_AverageReturn : 36.03571319580078
# Train_StdReturn : 16.112289428710938
# Train_MaxReturn : 95.0
# Train_MinReturn : 18.0
# Train_AverageEpLen : 36.035714285714285
# Actor Loss : 26711.3828125
# Train_EnvstepsSoFar : 5057
# TimeSinceStart : 3.624112844467163
# Done logging...
#
#
#
# ********** Iteration 5 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 38.90909194946289
# Eval_StdReturn : 12.894357681274414
# Eval_MaxReturn : 54.0
# Eval_MinReturn : 14.0
# Eval_AverageEpLen : 38.90909090909091
# Train_AverageReturn : 40.279998779296875
# Train_StdReturn : 21.170772552490234
# Train_MaxReturn : 107.0
# Train_MinReturn : 16.0
# Train_AverageEpLen : 40.28
# Actor Loss : 31420.521484375
# Train_EnvstepsSoFar : 6064
# TimeSinceStart : 4.163095712661743
# Done logging...
#
#
#
# ********** Iteration 6 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 44.55555725097656
# Eval_StdReturn : 18.117586135864258
# Eval_MaxReturn : 94.0
# Eval_MinReturn : 30.0
# Eval_AverageEpLen : 44.55555555555556
# Train_AverageReturn : 59.0
# Train_StdReturn : 41.47146224975586
# Train_MaxReturn : 200.0
# Train_MinReturn : 17.0
# Train_AverageEpLen : 59.0
# Actor Loss : 51832.44140625
# Train_EnvstepsSoFar : 7067
# TimeSinceStart : 4.724501132965088
# Done logging...
#
#
#
# ********** Iteration 7 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 46.88888931274414
# Eval_StdReturn : 20.545042037963867
# Eval_MaxReturn : 95.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 46.888888888888886
# Train_AverageReturn : 51.25
# Train_StdReturn : 18.74799919128418
# Train_MaxReturn : 118.0
# Train_MinReturn : 28.0
# Train_AverageEpLen : 51.25
# Actor Loss : 34179.578125
# Train_EnvstepsSoFar : 8092
# TimeSinceStart : 5.264322519302368
# Done logging...
#
#
#
# ********** Iteration 8 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 64.57142639160156
# Eval_StdReturn : 20.183849334716797
# Eval_MaxReturn : 106.0
# Eval_MinReturn : 40.0
# Eval_AverageEpLen : 64.57142857142857
# Train_AverageReturn : 59.411766052246094
# Train_StdReturn : 29.757963180541992
# Train_MaxReturn : 170.0
# Train_MinReturn : 34.0
# Train_AverageEpLen : 59.411764705882355
# Actor Loss : 41754.3359375
# Train_EnvstepsSoFar : 9102
# TimeSinceStart : 5.874653339385986
# Done logging...
#
#
#
# ********** Iteration 9 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 74.83333587646484
# Eval_StdReturn : 37.88762664794922
# Eval_MaxReturn : 132.0
# Eval_MinReturn : 42.0
# Eval_AverageEpLen : 74.83333333333333
# Train_AverageReturn : 80.23076629638672
# Train_StdReturn : 40.99559783935547
# Train_MaxReturn : 200.0
# Train_MinReturn : 36.0
# Train_AverageEpLen : 80.23076923076923
# Actor Loss : 58057.2421875
# Train_EnvstepsSoFar : 10145
# TimeSinceStart : 6.624696254730225
# Done logging...
#
#
#
# ********** Iteration 10 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 67.0
# Eval_StdReturn : 23.366641998291016
# Eval_MaxReturn : 108.0
# Eval_MinReturn : 38.0
# Eval_AverageEpLen : 67.0
# Train_AverageReturn : 73.21428680419922
# Train_StdReturn : 28.01321029663086
# Train_MaxReturn : 157.0
# Train_MinReturn : 39.0
# Train_AverageEpLen : 73.21428571428571
# Actor Loss : 46166.1171875
# Train_EnvstepsSoFar : 11170
# TimeSinceStart : 7.436377763748169
# Done logging...
#
#
#
# ********** Iteration 11 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 63.5
# Eval_StdReturn : 23.313085556030273
# Eval_MaxReturn : 111.0
# Eval_MinReturn : 39.0
# Eval_AverageEpLen : 63.5
# Train_AverageReturn : 62.117645263671875
# Train_StdReturn : 24.875886917114258
# Train_MaxReturn : 144.0
# Train_MinReturn : 37.0
# Train_AverageEpLen : 62.11764705882353
# Actor Loss : 39654.7890625
# Train_EnvstepsSoFar : 12226
# TimeSinceStart : 7.9976418018341064
# Done logging...
#
#
#
# ********** Iteration 12 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 62.0
# Eval_StdReturn : 10.028531074523926
# Eval_MaxReturn : 83.0
# Eval_MinReturn : 50.0
# Eval_AverageEpLen : 62.0
# Train_AverageReturn : 64.75
# Train_StdReturn : 17.9774169921875
# Train_MaxReturn : 97.0
# Train_MinReturn : 40.0
# Train_AverageEpLen : 64.75
# Actor Loss : 37288.00390625
# Train_EnvstepsSoFar : 13262
# TimeSinceStart : 8.680477619171143
# Done logging...
#
#
#
# ********** Iteration 13 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 68.16666412353516
# Eval_StdReturn : 14.519144058227539
# Eval_MaxReturn : 96.0
# Eval_MinReturn : 50.0
# Eval_AverageEpLen : 68.16666666666667
# Train_AverageReturn : 69.4000015258789
# Train_StdReturn : 19.001052856445312
# Train_MaxReturn : 104.0
# Train_MinReturn : 41.0
# Train_AverageEpLen : 69.4
# Actor Loss : 38197.3515625
# Train_EnvstepsSoFar : 14303
# TimeSinceStart : 9.251416206359863
# Done logging...
#
#
#
# ********** Iteration 14 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 65.71428680419922
# Eval_StdReturn : 13.781087875366211
# Eval_MaxReturn : 94.0
# Eval_MinReturn : 48.0
# Eval_AverageEpLen : 65.71428571428571
# Train_AverageReturn : 97.63636016845703
# Train_StdReturn : 31.675264358520508
# Train_MaxReturn : 159.0
# Train_MinReturn : 36.0
# Train_AverageEpLen : 97.63636363636364
# Actor Loss : 58730.40234375
# Train_EnvstepsSoFar : 15377
# TimeSinceStart : 9.837875604629517
# Done logging...
#
#
#
# ********** Iteration 15 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 100.5
# Eval_StdReturn : 21.5
# Eval_MaxReturn : 134.0
# Eval_MinReturn : 74.0
# Eval_AverageEpLen : 100.5
# Train_AverageReturn : 97.18181610107422
# Train_StdReturn : 39.960933685302734
# Train_MaxReturn : 200.0
# Train_MinReturn : 57.0
# Train_AverageEpLen : 97.18181818181819
# Actor Loss : 58017.43359375
# Train_EnvstepsSoFar : 16446
# TimeSinceStart : 10.399648904800415
# Done logging...
#
#
#
# ********** Iteration 16 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 135.3333282470703
# Eval_StdReturn : 41.50769805908203
# Eval_MaxReturn : 193.0
# Eval_MinReturn : 97.0
# Eval_AverageEpLen : 135.33333333333334
# Train_AverageReturn : 95.90908813476562
# Train_StdReturn : 25.53946876525879
# Train_MaxReturn : 138.0
# Train_MinReturn : 67.0
# Train_AverageEpLen : 95.9090909090909
# Actor Loss : 55615.1796875
# Train_EnvstepsSoFar : 17501
# TimeSinceStart : 10.995253562927246
# Done logging...
#
#
#
# ********** Iteration 17 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 114.0
# Eval_StdReturn : 35.249114990234375
# Eval_MaxReturn : 162.0
# Eval_MinReturn : 65.0
# Eval_AverageEpLen : 114.0
# Train_AverageReturn : 75.42857360839844
# Train_StdReturn : 19.264007568359375
# Train_MaxReturn : 129.0
# Train_MinReturn : 44.0
# Train_AverageEpLen : 75.42857142857143
# Actor Loss : 40729.796875
# Train_EnvstepsSoFar : 18557
# TimeSinceStart : 11.494215726852417
# Done logging...
#
#
#
# ********** Iteration 18 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 88.19999694824219
# Eval_StdReturn : 38.467647552490234
# Eval_MaxReturn : 144.0
# Eval_MinReturn : 45.0
# Eval_AverageEpLen : 88.2
# Train_AverageReturn : 108.69999694824219
# Train_StdReturn : 24.450153350830078
# Train_MaxReturn : 149.0
# Train_MinReturn : 83.0
# Train_AverageEpLen : 108.7
# Actor Loss : 60309.828125
# Train_EnvstepsSoFar : 19644
# TimeSinceStart : 12.0556058883667
# Done logging...
#
#
#
# ********** Iteration 19 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 83.19999694824219
# Eval_StdReturn : 32.884037017822266
# Eval_MaxReturn : 129.0
# Eval_MinReturn : 34.0
# Eval_AverageEpLen : 83.2
# Train_AverageReturn : 82.46154022216797
# Train_StdReturn : 27.424345016479492
# Train_MaxReturn : 144.0
# Train_MinReturn : 42.0
# Train_AverageEpLen : 82.46153846153847
# Actor Loss : 48950.5703125
# Train_EnvstepsSoFar : 20716
# TimeSinceStart : 12.710901260375977
# Done logging...
#
#
#
# ********** Iteration 20 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 105.5
# Eval_StdReturn : 50.6976318359375
# Eval_MaxReturn : 169.0
# Eval_MinReturn : 34.0
# Eval_AverageEpLen : 105.5
# Train_AverageReturn : 78.0
# Train_StdReturn : 24.118297576904297
# Train_MaxReturn : 121.0
# Train_MinReturn : 34.0
# Train_AverageEpLen : 78.0
# Actor Loss : 41871.6875
# Train_EnvstepsSoFar : 21730
# TimeSinceStart : 13.242604494094849
# Done logging...
#
#
#
# ********** Iteration 21 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 62.28571319580078
# Eval_StdReturn : 29.817129135131836
# Eval_MaxReturn : 129.0
# Eval_MinReturn : 37.0
# Eval_AverageEpLen : 62.285714285714285
# Train_AverageReturn : 71.92857360839844
# Train_StdReturn : 24.399837493896484
# Train_MaxReturn : 124.0
# Train_MinReturn : 44.0
# Train_AverageEpLen : 71.92857142857143
# Actor Loss : 39566.5078125
# Train_EnvstepsSoFar : 22737
# TimeSinceStart : 14.476780414581299
# Done logging...
#
#
#
# ********** Iteration 22 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 62.0
# Eval_StdReturn : 15.51036548614502
# Eval_MaxReturn : 87.0
# Eval_MinReturn : 41.0
# Eval_AverageEpLen : 62.0
# Train_AverageReturn : 72.64286041259766
# Train_StdReturn : 20.247072219848633
# Train_MaxReturn : 110.0
# Train_MinReturn : 43.0
# Train_AverageEpLen : 72.64285714285714
# Actor Loss : 38582.578125
# Train_EnvstepsSoFar : 23754
# TimeSinceStart : 15.828346967697144
# Done logging...
#
#
#
# ********** Iteration 23 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 70.66666412353516
# Eval_StdReturn : 36.07707595825195
# Eval_MaxReturn : 142.0
# Eval_MinReturn : 34.0
# Eval_AverageEpLen : 70.66666666666667
# Train_AverageReturn : 60.0
# Train_StdReturn : 25.884357452392578
# Train_MaxReturn : 128.0
# Train_MinReturn : 31.0
# Train_AverageEpLen : 60.0
# Actor Loss : 36854.875
# Train_EnvstepsSoFar : 24774
# TimeSinceStart : 17.01409888267517
# Done logging...
#
#
#
# ********** Iteration 24 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 56.75
# Eval_StdReturn : 15.841007232666016
# Eval_MaxReturn : 81.0
# Eval_MinReturn : 36.0
# Eval_AverageEpLen : 56.75
# Train_AverageReturn : 63.0
# Train_StdReturn : 15.508062362670898
# Train_MaxReturn : 95.0
# Train_MinReturn : 43.0
# Train_AverageEpLen : 63.0
# Actor Loss : 34020.015625
# Train_EnvstepsSoFar : 25782
# TimeSinceStart : 18.3118736743927
# Done logging...
#
#
#
# ********** Iteration 25 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 54.75
# Eval_StdReturn : 14.015616416931152
# Eval_MaxReturn : 83.0
# Eval_MinReturn : 38.0
# Eval_AverageEpLen : 54.75
# Train_AverageReturn : 67.26667022705078
# Train_StdReturn : 27.416460037231445
# Train_MaxReturn : 129.0
# Train_MinReturn : 24.0
# Train_AverageEpLen : 67.26666666666667
# Actor Loss : 40056.671875
# Train_EnvstepsSoFar : 26791
# TimeSinceStart : 19.025775909423828
# Done logging...
#
#
#
# ********** Iteration 26 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 64.42857360839844
# Eval_StdReturn : 14.76344108581543
# Eval_MaxReturn : 85.0
# Eval_MinReturn : 38.0
# Eval_AverageEpLen : 64.42857142857143
# Train_AverageReturn : 79.0
# Train_StdReturn : 38.86465835571289
# Train_MaxReturn : 172.0
# Train_MinReturn : 32.0
# Train_AverageEpLen : 79.0
# Actor Loss : 51214.3203125
# Train_EnvstepsSoFar : 27818
# TimeSinceStart : 19.624991178512573
# Done logging...
#
#
#
# ********** Iteration 27 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 74.33333587646484
# Eval_StdReturn : 25.759571075439453
# Eval_MaxReturn : 120.0
# Eval_MinReturn : 36.0
# Eval_AverageEpLen : 74.33333333333333
# Train_AverageReturn : 78.71428680419922
# Train_StdReturn : 39.090423583984375
# Train_MaxReturn : 180.0
# Train_MinReturn : 41.0
# Train_AverageEpLen : 78.71428571428571
# Actor Loss : 53529.5859375
# Train_EnvstepsSoFar : 28920
# TimeSinceStart : 20.1528160572052
# Done logging...
#
#
#
# ********** Iteration 28 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 87.19999694824219
# Eval_StdReturn : 13.242356300354004
# Eval_MaxReturn : 109.0
# Eval_MinReturn : 70.0
# Eval_AverageEpLen : 87.2
# Train_AverageReturn : 82.15384674072266
# Train_StdReturn : 18.446788787841797
# Train_MaxReturn : 126.0
# Train_MinReturn : 57.0
# Train_AverageEpLen : 82.15384615384616
# Actor Loss : 46404.828125
# Train_EnvstepsSoFar : 29988
# TimeSinceStart : 20.632760047912598
# Done logging...
#
#
#
# ********** Iteration 29 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 135.0
# Eval_StdReturn : 31.874753952026367
# Eval_MaxReturn : 175.0
# Eval_MinReturn : 97.0
# Eval_AverageEpLen : 135.0
# Train_AverageReturn : 85.33333587646484
# Train_StdReturn : 31.3111629486084
# Train_MaxReturn : 146.0
# Train_MinReturn : 43.0
# Train_AverageEpLen : 85.33333333333333
# Actor Loss : 49247.7265625
# Train_EnvstepsSoFar : 31012
# TimeSinceStart : 21.165491819381714
# Done logging...
#
#
#
# ********** Iteration 30 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 90.4000015258789
# Eval_StdReturn : 21.81375503540039
# Eval_MaxReturn : 110.0
# Eval_MinReturn : 51.0
# Eval_AverageEpLen : 90.4
# Train_AverageReturn : 83.41666412353516
# Train_StdReturn : 31.531620025634766
# Train_MaxReturn : 138.0
# Train_MinReturn : 50.0
# Train_AverageEpLen : 83.41666666666667
# Actor Loss : 46982.9140625
# Train_EnvstepsSoFar : 32013
# TimeSinceStart : 21.624747276306152
# Done logging...
#
#
#
# ********** Iteration 31 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 86.19999694824219
# Eval_StdReturn : 28.095550537109375
# Eval_MaxReturn : 121.0
# Eval_MinReturn : 49.0
# Eval_AverageEpLen : 86.2
# Train_AverageReturn : 82.76923370361328
# Train_StdReturn : 27.406213760375977
# Train_MaxReturn : 152.0
# Train_MinReturn : 45.0
# Train_AverageEpLen : 82.76923076923077
# Actor Loss : 49653.5859375
# Train_EnvstepsSoFar : 33089
# TimeSinceStart : 22.315428018569946
# Done logging...
#
#
#
# ********** Iteration 32 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 77.83333587646484
# Eval_StdReturn : 35.2014045715332
# Eval_MaxReturn : 150.0
# Eval_MinReturn : 43.0
# Eval_AverageEpLen : 77.83333333333333
# Train_AverageReturn : 93.36363983154297
# Train_StdReturn : 39.036746978759766
# Train_MaxReturn : 196.0
# Train_MinReturn : 43.0
# Train_AverageEpLen : 93.36363636363636
# Actor Loss : 54957.15234375
# Train_EnvstepsSoFar : 34116
# TimeSinceStart : 22.85901141166687
# Done logging...
#
#
#
# ********** Iteration 33 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 57.57143020629883
# Eval_StdReturn : 12.703848838806152
# Eval_MaxReturn : 75.0
# Eval_MinReturn : 40.0
# Eval_AverageEpLen : 57.57142857142857
# Train_AverageReturn : 66.86666870117188
# Train_StdReturn : 29.14301872253418
# Train_MaxReturn : 150.0
# Train_MinReturn : 36.0
# Train_AverageEpLen : 66.86666666666666
# Actor Loss : 40802.47265625
# Train_EnvstepsSoFar : 35119
# TimeSinceStart : 23.540470361709595
# Done logging...
#
#
#
# ********** Iteration 34 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 45.88888931274414
# Eval_StdReturn : 8.332592964172363
# Eval_MaxReturn : 63.0
# Eval_MinReturn : 36.0
# Eval_AverageEpLen : 45.888888888888886
# Train_AverageReturn : 59.764705657958984
# Train_StdReturn : 21.585750579833984
# Train_MaxReturn : 98.0
# Train_MinReturn : 28.0
# Train_AverageEpLen : 59.76470588235294
# Actor Loss : 33850.7265625
# Train_EnvstepsSoFar : 36135
# TimeSinceStart : 24.02915930747986
# Done logging...
#
#
#
# ********** Iteration 35 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 56.0
# Eval_StdReturn : 8.2915620803833
# Eval_MaxReturn : 68.0
# Eval_MinReturn : 43.0
# Eval_AverageEpLen : 56.0
# Train_AverageReturn : 53.52631759643555
# Train_StdReturn : 14.150947570800781
# Train_MaxReturn : 90.0
# Train_MinReturn : 29.0
# Train_AverageEpLen : 53.526315789473685
# Actor Loss : 28352.83984375
# Train_EnvstepsSoFar : 37152
# TimeSinceStart : 24.965736865997314
# Done logging...
#
#
#
# ********** Iteration 36 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 49.0
# Eval_StdReturn : 14.560219764709473
# Eval_MaxReturn : 81.0
# Eval_MinReturn : 30.0
# Eval_AverageEpLen : 49.0
# Train_AverageReturn : 50.400001525878906
# Train_StdReturn : 11.555951118469238
# Train_MaxReturn : 77.0
# Train_MinReturn : 28.0
# Train_AverageEpLen : 50.4
# Actor Loss : 27149.763671875
# Train_EnvstepsSoFar : 38160
# TimeSinceStart : 25.556067943572998
# Done logging...
#
#
#
# ********** Iteration 37 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 47.88888931274414
# Eval_StdReturn : 11.50308609008789
# Eval_MaxReturn : 75.0
# Eval_MinReturn : 35.0
# Eval_AverageEpLen : 47.888888888888886
# Train_AverageReturn : 51.04999923706055
# Train_StdReturn : 14.58929443359375
# Train_MaxReturn : 82.0
# Train_MinReturn : 32.0
# Train_AverageEpLen : 51.05
# Actor Loss : 28855.65625
# Train_EnvstepsSoFar : 39181
# TimeSinceStart : 26.131730318069458
# Done logging...
#
#
#
# ********** Iteration 38 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 45.77777862548828
# Eval_StdReturn : 14.16394329071045
# Eval_MaxReturn : 78.0
# Eval_MinReturn : 31.0
# Eval_AverageEpLen : 45.77777777777778
# Train_AverageReturn : 47.619049072265625
# Train_StdReturn : 12.330666542053223
# Train_MaxReturn : 74.0
# Train_MinReturn : 27.0
# Train_AverageEpLen : 47.61904761904762
# Actor Loss : 25150.9765625
# Train_EnvstepsSoFar : 40181
# TimeSinceStart : 26.658095121383667
# Done logging...
#
#
#
# ********** Iteration 39 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 50.375
# Eval_StdReturn : 6.762719631195068
# Eval_MaxReturn : 63.0
# Eval_MinReturn : 41.0
# Eval_AverageEpLen : 50.375
# Train_AverageReturn : 51.150001525878906
# Train_StdReturn : 13.598804473876953
# Train_MaxReturn : 79.0
# Train_MinReturn : 27.0
# Train_AverageEpLen : 51.15
# Actor Loss : 28984.16015625
# Train_EnvstepsSoFar : 41204
# TimeSinceStart : 27.158870935440063
# Done logging...
#
#
#
# ********** Iteration 40 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 71.83333587646484
# Eval_StdReturn : 38.137542724609375
# Eval_MaxReturn : 156.0
# Eval_MinReturn : 47.0
# Eval_AverageEpLen : 71.83333333333333
# Train_AverageReturn : 48.80952453613281
# Train_StdReturn : 13.489392280578613
# Train_MaxReturn : 75.0
# Train_MinReturn : 25.0
# Train_AverageEpLen : 48.80952380952381
# Actor Loss : 27216.328125
# Train_EnvstepsSoFar : 42229
# TimeSinceStart : 27.658594131469727
# Done logging...
#
#
#
# ********** Iteration 41 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 48.33333206176758
# Eval_StdReturn : 14.251705169677734
# Eval_MaxReturn : 79.0
# Eval_MinReturn : 34.0
# Eval_AverageEpLen : 48.333333333333336
# Train_AverageReturn : 46.772727966308594
# Train_StdReturn : 15.403459548950195
# Train_MaxReturn : 81.0
# Train_MinReturn : 26.0
# Train_AverageEpLen : 46.77272727272727
# Actor Loss : 27018.51171875
# Train_EnvstepsSoFar : 43258
# TimeSinceStart : 28.32472324371338
# Done logging...
#
#
#
# ********** Iteration 42 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 55.0
# Eval_StdReturn : 25.135189056396484
# Eval_MaxReturn : 124.0
# Eval_MinReturn : 40.0
# Eval_AverageEpLen : 55.0
# Train_AverageReturn : 48.0476188659668
# Train_StdReturn : 18.093608856201172
# Train_MaxReturn : 101.0
# Train_MinReturn : 28.0
# Train_AverageEpLen : 48.04761904761905
# Actor Loss : 28502.41796875
# Train_EnvstepsSoFar : 44267
# TimeSinceStart : 29.258696794509888
# Done logging...
#
#
#
# ********** Iteration 43 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 54.375
# Eval_StdReturn : 9.733158111572266
# Eval_MaxReturn : 73.0
# Eval_MinReturn : 40.0
# Eval_AverageEpLen : 54.375
# Train_AverageReturn : 52.68421173095703
# Train_StdReturn : 16.377304077148438
# Train_MaxReturn : 89.0
# Train_MinReturn : 31.0
# Train_AverageEpLen : 52.68421052631579
# Actor Loss : 30901.10546875
# Train_EnvstepsSoFar : 45268
# TimeSinceStart : 30.094284057617188
# Done logging...
#
#
#
# ********** Iteration 44 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 50.33333206176758
# Eval_StdReturn : 10.274023056030273
# Eval_MaxReturn : 72.0
# Eval_MinReturn : 38.0
# Eval_AverageEpLen : 50.333333333333336
# Train_AverageReturn : 46.272727966308594
# Train_StdReturn : 15.430728912353516
# Train_MaxReturn : 86.0
# Train_MinReturn : 24.0
# Train_AverageEpLen : 46.27272727272727
# Actor Loss : 28164.1328125
# Train_EnvstepsSoFar : 46286
# TimeSinceStart : 31.08884024620056
# Done logging...
#
#
#
# ********** Iteration 45 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 54.375
# Eval_StdReturn : 24.642126083374023
# Eval_MaxReturn : 106.0
# Eval_MinReturn : 32.0
# Eval_AverageEpLen : 54.375
# Train_AverageReturn : 52.29999923706055
# Train_StdReturn : 20.914348602294922
# Train_MaxReturn : 125.0
# Train_MinReturn : 26.0
# Train_AverageEpLen : 52.3
# Actor Loss : 33771.4140625
# Train_EnvstepsSoFar : 47332
# TimeSinceStart : 31.779767990112305
# Done logging...
#
#
#
# ********** Iteration 46 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 52.400001525878906
# Eval_StdReturn : 27.6990966796875
# Eval_MaxReturn : 130.0
# Eval_MinReturn : 30.0
# Eval_AverageEpLen : 52.4
# Train_AverageReturn : 72.5
# Train_StdReturn : 43.319000244140625
# Train_MaxReturn : 200.0
# Train_MinReturn : 39.0
# Train_AverageEpLen : 72.5
# Actor Loss : 52592.18359375
# Train_EnvstepsSoFar : 48347
# TimeSinceStart : 32.56447076797485
# Done logging...
#
#
#
# ********** Iteration 47 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 46.44444274902344
# Eval_StdReturn : 11.53844928741455
# Eval_MaxReturn : 62.0
# Eval_MinReturn : 32.0
# Eval_AverageEpLen : 46.44444444444444
# Train_AverageReturn : 59.0
# Train_StdReturn : 25.307519912719727
# Train_MaxReturn : 139.0
# Train_MinReturn : 34.0
# Train_AverageEpLen : 59.0
# Actor Loss : 37298.58203125
# Train_EnvstepsSoFar : 49350
# TimeSinceStart : 33.43796944618225
# Done logging...
#
#
#
# ********** Iteration 48 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 48.33333206176758
# Eval_StdReturn : 10.154364585876465
# Eval_MaxReturn : 67.0
# Eval_MinReturn : 34.0
# Eval_AverageEpLen : 48.333333333333336
# Train_AverageReturn : 54.6315803527832
# Train_StdReturn : 19.167436599731445
# Train_MaxReturn : 106.0
# Train_MinReturn : 31.0
# Train_AverageEpLen : 54.63157894736842
# Actor Loss : 33665.40625
# Train_EnvstepsSoFar : 50388
# TimeSinceStart : 34.19336795806885
# Done logging...
#
#
#
# ********** Iteration 49 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 71.0
# Eval_StdReturn : 28.89059829711914
# Eval_MaxReturn : 120.0
# Eval_MinReturn : 34.0
# Eval_AverageEpLen : 71.0
# Train_AverageReturn : 62.6875
# Train_StdReturn : 24.512035369873047
# Train_MaxReturn : 143.0
# Train_MinReturn : 30.0
# Train_AverageEpLen : 62.6875
# Actor Loss : 38877.15625
# Train_EnvstepsSoFar : 51391
# TimeSinceStart : 35.70772433280945
# Done logging...
#
#
#
# ********** Iteration 50 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 108.19999694824219
# Eval_StdReturn : 33.42693328857422
# Eval_MaxReturn : 164.0
# Eval_MinReturn : 68.0
# Eval_AverageEpLen : 108.2
# Train_AverageReturn : 59.22222137451172
# Train_StdReturn : 19.741540908813477
# Train_MaxReturn : 108.0
# Train_MinReturn : 31.0
# Train_AverageEpLen : 59.22222222222222
# Actor Loss : 36662.79296875
# Train_EnvstepsSoFar : 52457
# TimeSinceStart : 36.471757650375366
# Done logging...
#
#
#
# ********** Iteration 51 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 63.42856979370117
# Eval_StdReturn : 14.888703346252441
# Eval_MaxReturn : 83.0
# Eval_MinReturn : 37.0
# Eval_AverageEpLen : 63.42857142857143
# Train_AverageReturn : 77.30769348144531
# Train_StdReturn : 29.10031509399414
# Train_MaxReturn : 157.0
# Train_MinReturn : 52.0
# Train_AverageEpLen : 77.3076923076923
# Actor Loss : 45964.3125
# Train_EnvstepsSoFar : 53462
# TimeSinceStart : 37.10797619819641
# Done logging...
#
#
#
# ********** Iteration 52 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 83.66666412353516
# Eval_StdReturn : 52.80677795410156
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 48.0
# Eval_AverageEpLen : 83.66666666666667
# Train_AverageReturn : 66.1875
# Train_StdReturn : 16.651647567749023
# Train_MaxReturn : 108.0
# Train_MinReturn : 31.0
# Train_AverageEpLen : 66.1875
# Actor Loss : 38915.3984375
# Train_EnvstepsSoFar : 54521
# TimeSinceStart : 37.59293055534363
# Done logging...
#
#
#
# ********** Iteration 53 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 81.4000015258789
# Eval_StdReturn : 29.648609161376953
# Eval_MaxReturn : 125.0
# Eval_MinReturn : 42.0
# Eval_AverageEpLen : 81.4
# Train_AverageReturn : 71.5
# Train_StdReturn : 25.44672203063965
# Train_MaxReturn : 126.0
# Train_MinReturn : 40.0
# Train_AverageEpLen : 71.5
# Actor Loss : 40874.06640625
# Train_EnvstepsSoFar : 55522
# TimeSinceStart : 38.179829359054565
# Done logging...
#
#
#
# ********** Iteration 54 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 77.0
# Eval_StdReturn : 12.206555366516113
# Eval_MaxReturn : 90.0
# Eval_MinReturn : 54.0
# Eval_AverageEpLen : 77.0
# Train_AverageReturn : 76.35713958740234
# Train_StdReturn : 33.75882339477539
# Train_MaxReturn : 151.0
# Train_MinReturn : 38.0
# Train_AverageEpLen : 76.35714285714286
# Actor Loss : 50549.9921875
# Train_EnvstepsSoFar : 56591
# TimeSinceStart : 38.69083833694458
# Done logging...
#
#
#
# ********** Iteration 55 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 92.0
# Eval_StdReturn : 27.327640533447266
# Eval_MaxReturn : 122.0
# Eval_MinReturn : 50.0
# Eval_AverageEpLen : 92.0
# Train_AverageReturn : 87.16666412353516
# Train_StdReturn : 28.20707130432129
# Train_MaxReturn : 137.0
# Train_MinReturn : 42.0
# Train_AverageEpLen : 87.16666666666667
# Actor Loss : 50843.88671875
# Train_EnvstepsSoFar : 57637
# TimeSinceStart : 39.353538513183594
# Done logging...
#
#
#
# ********** Iteration 56 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 80.0
# Eval_StdReturn : 25.432262420654297
# Eval_MaxReturn : 114.0
# Eval_MinReturn : 45.0
# Eval_AverageEpLen : 80.0
# Train_AverageReturn : 92.7272720336914
# Train_StdReturn : 40.979129791259766
# Train_MaxReturn : 200.0
# Train_MinReturn : 52.0
# Train_AverageEpLen : 92.72727272727273
# Actor Loss : 56549.375
# Train_EnvstepsSoFar : 58657
# TimeSinceStart : 39.90546727180481
# Done logging...
#
#
#
# ********** Iteration 57 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 87.0
# Eval_StdReturn : 27.784887313842773
# Eval_MaxReturn : 124.0
# Eval_MinReturn : 51.0
# Eval_AverageEpLen : 87.0
# Train_AverageReturn : 79.61538696289062
# Train_StdReturn : 30.078201293945312
# Train_MaxReturn : 173.0
# Train_MinReturn : 44.0
# Train_AverageEpLen : 79.61538461538461
# Actor Loss : 47924.74609375
# Train_EnvstepsSoFar : 59692
# TimeSinceStart : 40.49255084991455
# Done logging...
#
#
#
# ********** Iteration 58 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 80.0
# Eval_StdReturn : 17.549928665161133
# Eval_MaxReturn : 113.0
# Eval_MinReturn : 61.0
# Eval_AverageEpLen : 80.0
# Train_AverageReturn : 85.64286041259766
# Train_StdReturn : 39.92422866821289
# Train_MaxReturn : 200.0
# Train_MinReturn : 45.0
# Train_AverageEpLen : 85.64285714285714
# Actor Loss : 62381.515625
# Train_EnvstepsSoFar : 60891
# TimeSinceStart : 41.098315954208374
# Done logging...
#
#
#
# ********** Iteration 59 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 83.5999984741211
# Eval_StdReturn : 30.11710548400879
# Eval_MaxReturn : 129.0
# Eval_MinReturn : 53.0
# Eval_AverageEpLen : 83.6
# Train_AverageReturn : 75.78571319580078
# Train_StdReturn : 29.756580352783203
# Train_MaxReturn : 152.0
# Train_MinReturn : 33.0
# Train_AverageEpLen : 75.78571428571429
# Actor Loss : 46661.36328125
# Train_EnvstepsSoFar : 61952
# TimeSinceStart : 41.62196445465088
# Done logging...
#
#
#
# ********** Iteration 60 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 52.125
# Eval_StdReturn : 17.737232208251953
# Eval_MaxReturn : 97.0
# Eval_MinReturn : 35.0
# Eval_AverageEpLen : 52.125
# Train_AverageReturn : 71.42857360839844
# Train_StdReturn : 16.413036346435547
# Train_MaxReturn : 99.0
# Train_MinReturn : 31.0
# Train_AverageEpLen : 71.42857142857143
# Actor Loss : 37750.92578125
# Train_EnvstepsSoFar : 62952
# TimeSinceStart : 42.19537663459778
# Done logging...
#
#
#
# ********** Iteration 61 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 57.125
# Eval_StdReturn : 18.53670310974121
# Eval_MaxReturn : 85.0
# Eval_MinReturn : 31.0
# Eval_AverageEpLen : 57.125
# Train_AverageReturn : 64.9375
# Train_StdReturn : 26.70549774169922
# Train_MaxReturn : 158.0
# Train_MinReturn : 42.0
# Train_AverageEpLen : 64.9375
# Actor Loss : 38997.16015625
# Train_EnvstepsSoFar : 63991
# TimeSinceStart : 42.750715017318726
# Done logging...
#
#
#
# ********** Iteration 62 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 61.25
# Eval_StdReturn : 21.735628128051758
# Eval_MaxReturn : 102.0
# Eval_MinReturn : 40.0
# Eval_AverageEpLen : 61.25
# Train_AverageReturn : 60.29411697387695
# Train_StdReturn : 16.305049896240234
# Train_MaxReturn : 92.0
# Train_MinReturn : 38.0
# Train_AverageEpLen : 60.294117647058826
# Actor Loss : 32749.4375
# Train_EnvstepsSoFar : 65016
# TimeSinceStart : 43.702569007873535
# Done logging...
#
#
#
# ********** Iteration 63 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 47.11111068725586
# Eval_StdReturn : 21.2939453125
# Eval_MaxReturn : 103.0
# Eval_MinReturn : 30.0
# Eval_AverageEpLen : 47.111111111111114
# Train_AverageReturn : 67.875
# Train_StdReturn : 29.601255416870117
# Train_MaxReturn : 142.0
# Train_MinReturn : 37.0
# Train_AverageEpLen : 67.875
# Actor Loss : 44853.19140625
# Train_EnvstepsSoFar : 66102
# TimeSinceStart : 44.35392475128174
# Done logging...
#
#
#
# ********** Iteration 64 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 55.88888931274414
# Eval_StdReturn : 26.082963943481445
# Eval_MaxReturn : 113.0
# Eval_MinReturn : 31.0
# Eval_AverageEpLen : 55.888888888888886
# Train_AverageReturn : 53.157894134521484
# Train_StdReturn : 15.815593719482422
# Train_MaxReturn : 98.0
# Train_MinReturn : 30.0
# Train_AverageEpLen : 53.1578947368421
# Actor Loss : 29446.4140625
# Train_EnvstepsSoFar : 67112
# TimeSinceStart : 45.15125489234924
# Done logging...
#
#
#
# ********** Iteration 65 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 67.33333587646484
# Eval_StdReturn : 20.154956817626953
# Eval_MaxReturn : 110.0
# Eval_MinReturn : 49.0
# Eval_AverageEpLen : 67.33333333333333
# Train_AverageReturn : 63.1875
# Train_StdReturn : 33.32645034790039
# Train_MaxReturn : 179.0
# Train_MinReturn : 33.0
# Train_AverageEpLen : 63.1875
# Actor Loss : 41553.546875
# Train_EnvstepsSoFar : 68123
# TimeSinceStart : 45.83222579956055
# Done logging...
#
#
#
# ********** Iteration 66 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 61.0
# Eval_StdReturn : 10.928338050842285
# Eval_MaxReturn : 80.0
# Eval_MinReturn : 43.0
# Eval_AverageEpLen : 61.0
# Train_AverageReturn : 59.70588302612305
# Train_StdReturn : 17.904205322265625
# Train_MaxReturn : 88.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 59.705882352941174
# Actor Loss : 31733.76953125
# Train_EnvstepsSoFar : 69138
# TimeSinceStart : 46.601643323898315
# Done logging...
#
#
#
# ********** Iteration 67 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 63.5
# Eval_StdReturn : 22.945587158203125
# Eval_MaxReturn : 113.0
# Eval_MinReturn : 35.0
# Eval_AverageEpLen : 63.5
# Train_AverageReturn : 60.38888931274414
# Train_StdReturn : 18.93890380859375
# Train_MaxReturn : 119.0
# Train_MinReturn : 33.0
# Train_AverageEpLen : 60.388888888888886
# Actor Loss : 36186.6015625
# Train_EnvstepsSoFar : 70225
# TimeSinceStart : 47.2089741230011
# Done logging...
#
#
#
# ********** Iteration 68 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 58.71428680419922
# Eval_StdReturn : 14.379690170288086
# Eval_MaxReturn : 84.0
# Eval_MinReturn : 36.0
# Eval_AverageEpLen : 58.714285714285715
# Train_AverageReturn : 64.35294342041016
# Train_StdReturn : 24.144031524658203
# Train_MaxReturn : 119.0
# Train_MinReturn : 35.0
# Train_AverageEpLen : 64.3529411764706
# Actor Loss : 40632.01171875
# Train_EnvstepsSoFar : 71319
# TimeSinceStart : 47.78554368019104
# Done logging...
#
#
#
# ********** Iteration 69 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 94.19999694824219
# Eval_StdReturn : 13.991426467895508
# Eval_MaxReturn : 117.0
# Eval_MinReturn : 77.0
# Eval_AverageEpLen : 94.2
# Train_AverageReturn : 68.86666870117188
# Train_StdReturn : 32.18046188354492
# Train_MaxReturn : 181.0
# Train_MinReturn : 39.0
# Train_AverageEpLen : 68.86666666666666
# Actor Loss : 41826.0234375
# Train_EnvstepsSoFar : 72352
# TimeSinceStart : 48.30323266983032
# Done logging...
#
#
#
# ********** Iteration 70 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 73.83333587646484
# Eval_StdReturn : 22.40845489501953
# Eval_MaxReturn : 118.0
# Eval_MinReturn : 47.0
# Eval_AverageEpLen : 73.83333333333333
# Train_AverageReturn : 79.30769348144531
# Train_StdReturn : 23.869468688964844
# Train_MaxReturn : 125.0
# Train_MinReturn : 43.0
# Train_AverageEpLen : 79.3076923076923
# Actor Loss : 44588.95703125
# Train_EnvstepsSoFar : 73383
# TimeSinceStart : 48.76111555099487
# Done logging...
#
#
#
# ********** Iteration 71 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 89.0
# Eval_StdReturn : 26.313495635986328
# Eval_MaxReturn : 131.0
# Eval_MinReturn : 60.0
# Eval_AverageEpLen : 89.0
# Train_AverageReturn : 77.53845977783203
# Train_StdReturn : 29.106212615966797
# Train_MaxReturn : 136.0
# Train_MinReturn : 36.0
# Train_AverageEpLen : 77.53846153846153
# Actor Loss : 41771.86328125
# Train_EnvstepsSoFar : 74391
# TimeSinceStart : 49.225051403045654
# Done logging...
#
#
#
# ********** Iteration 72 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 87.16666412353516
# Eval_StdReturn : 24.141366958618164
# Eval_MaxReturn : 128.0
# Eval_MinReturn : 51.0
# Eval_AverageEpLen : 87.16666666666667
# Train_AverageReturn : 94.33333587646484
# Train_StdReturn : 25.817737579345703
# Train_MaxReturn : 164.0
# Train_MinReturn : 64.0
# Train_AverageEpLen : 94.33333333333333
# Actor Loss : 55182.73046875
# Train_EnvstepsSoFar : 75523
# TimeSinceStart : 49.83314490318298
# Done logging...
#
#
#
# ********** Iteration 73 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 71.5
# Eval_StdReturn : 17.442764282226562
# Eval_MaxReturn : 104.0
# Eval_MinReturn : 47.0
# Eval_AverageEpLen : 71.5
# Train_AverageReturn : 94.16666412353516
# Train_StdReturn : 39.05302429199219
# Train_MaxReturn : 200.0
# Train_MinReturn : 46.0
# Train_AverageEpLen : 94.16666666666667
# Actor Loss : 58985.7890625
# Train_EnvstepsSoFar : 76653
# TimeSinceStart : 50.371114015579224
# Done logging...
#
#
#
# ********** Iteration 74 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 83.5999984741211
# Eval_StdReturn : 19.49974250793457
# Eval_MaxReturn : 115.0
# Eval_MinReturn : 60.0
# Eval_AverageEpLen : 83.6
# Train_AverageReturn : 85.66666412353516
# Train_StdReturn : 13.492795944213867
# Train_MaxReturn : 104.0
# Train_MinReturn : 66.0
# Train_AverageEpLen : 85.66666666666667
# Actor Loss : 42500.5234375
# Train_EnvstepsSoFar : 77681
# TimeSinceStart : 50.91454815864563
# Done logging...
#
#
#
# ********** Iteration 75 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 95.4000015258789
# Eval_StdReturn : 14.221110343933105
# Eval_MaxReturn : 114.0
# Eval_MinReturn : 78.0
# Eval_AverageEpLen : 95.4
# Train_AverageReturn : 100.2727279663086
# Train_StdReturn : 25.842498779296875
# Train_MaxReturn : 145.0
# Train_MinReturn : 69.0
# Train_AverageEpLen : 100.27272727272727
# Actor Loss : 54939.2578125
# Train_EnvstepsSoFar : 78784
# TimeSinceStart : 51.48788332939148
# Done logging...
#
#
#
# ********** Iteration 76 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 91.19999694824219
# Eval_StdReturn : 14.4138822555542
# Eval_MaxReturn : 117.0
# Eval_MinReturn : 78.0
# Eval_AverageEpLen : 91.2
# Train_AverageReturn : 106.80000305175781
# Train_StdReturn : 22.617692947387695
# Train_MaxReturn : 156.0
# Train_MinReturn : 80.0
# Train_AverageEpLen : 106.8
# Actor Loss : 56581.5859375
# Train_EnvstepsSoFar : 79852
# TimeSinceStart : 51.967610120773315
# Done logging...
#
#
#
# ********** Iteration 77 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 86.80000305175781
# Eval_StdReturn : 34.10219955444336
# Eval_MaxReturn : 146.0
# Eval_MinReturn : 52.0
# Eval_AverageEpLen : 86.8
# Train_AverageReturn : 99.0
# Train_StdReturn : 22.291458129882812
# Train_MaxReturn : 149.0
# Train_MinReturn : 68.0
# Train_AverageEpLen : 99.0
# Actor Loss : 51938.84375
# Train_EnvstepsSoFar : 80941
# TimeSinceStart : 52.59250569343567
# Done logging...
#
#
#
# ********** Iteration 78 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 90.4000015258789
# Eval_StdReturn : 12.626955032348633
# Eval_MaxReturn : 112.0
# Eval_MinReturn : 74.0
# Eval_AverageEpLen : 90.4
# Train_AverageReturn : 92.45454406738281
# Train_StdReturn : 16.244516372680664
# Train_MaxReturn : 121.0
# Train_MinReturn : 66.0
# Train_AverageEpLen : 92.45454545454545
# Actor Loss : 44041.7890625
# Train_EnvstepsSoFar : 81958
# TimeSinceStart : 53.220715045928955
# Done logging...
#
#
#
# ********** Iteration 79 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 83.4000015258789
# Eval_StdReturn : 11.324310302734375
# Eval_MaxReturn : 105.0
# Eval_MinReturn : 73.0
# Eval_AverageEpLen : 83.4
# Train_AverageReturn : 94.81818389892578
# Train_StdReturn : 20.625749588012695
# Train_MaxReturn : 144.0
# Train_MinReturn : 68.0
# Train_AverageEpLen : 94.81818181818181
# Actor Loss : 46948.65625
# Train_EnvstepsSoFar : 83001
# TimeSinceStart : 53.806233406066895
# Done logging...
#
#
#
# ********** Iteration 80 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 92.80000305175781
# Eval_StdReturn : 19.762590408325195
# Eval_MaxReturn : 119.0
# Eval_MinReturn : 65.0
# Eval_AverageEpLen : 92.8
# Train_AverageReturn : 91.09091186523438
# Train_StdReturn : 15.945672035217285
# Train_MaxReturn : 122.0
# Train_MinReturn : 71.0
# Train_AverageEpLen : 91.0909090909091
# Actor Loss : 42191.5078125
# Train_EnvstepsSoFar : 84003
# TimeSinceStart : 54.39491844177246
# Done logging...
#
#
#
# ********** Iteration 81 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 85.5999984741211
# Eval_StdReturn : 23.39743423461914
# Eval_MaxReturn : 124.0
# Eval_MinReturn : 64.0
# Eval_AverageEpLen : 85.6
# Train_AverageReturn : 114.44444274902344
# Train_StdReturn : 28.71744155883789
# Train_MaxReturn : 158.0
# Train_MinReturn : 82.0
# Train_AverageEpLen : 114.44444444444444
# Actor Loss : 53795.125
# Train_EnvstepsSoFar : 85033
# TimeSinceStart : 55.075035095214844
# Done logging...
#
#
#
# ********** Iteration 82 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 110.75
# Eval_StdReturn : 37.96955871582031
# Eval_MaxReturn : 172.0
# Eval_MinReturn : 70.0
# Eval_AverageEpLen : 110.75
# Train_AverageReturn : 98.90908813476562
# Train_StdReturn : 21.292142868041992
# Train_MaxReturn : 141.0
# Train_MinReturn : 67.0
# Train_AverageEpLen : 98.9090909090909
# Actor Loss : 48779.07421875
# Train_EnvstepsSoFar : 86121
# TimeSinceStart : 55.66624045372009
# Done logging...
#
#
#
# ********** Iteration 83 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 108.5
# Eval_StdReturn : 53.84468460083008
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 62.0
# Eval_AverageEpLen : 108.5
# Train_AverageReturn : 100.5
# Train_StdReturn : 28.39806365966797
# Train_MaxReturn : 173.0
# Train_MinReturn : 62.0
# Train_AverageEpLen : 100.5
# Actor Loss : 47363.828125
# Train_EnvstepsSoFar : 87126
# TimeSinceStart : 56.61814856529236
# Done logging...
#
#
#
# ********** Iteration 84 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 84.4000015258789
# Eval_StdReturn : 14.813507080078125
# Eval_MaxReturn : 108.0
# Eval_MinReturn : 68.0
# Eval_AverageEpLen : 84.4
# Train_AverageReturn : 97.5
# Train_StdReturn : 26.36443328857422
# Train_MaxReturn : 171.0
# Train_MinReturn : 74.0
# Train_AverageEpLen : 97.5
# Actor Loss : 51355.4765625
# Train_EnvstepsSoFar : 88296
# TimeSinceStart : 57.17368769645691
# Done logging...
#
#
#
# ********** Iteration 85 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 96.80000305175781
# Eval_StdReturn : 29.01999282836914
# Eval_MaxReturn : 151.0
# Eval_MinReturn : 64.0
# Eval_AverageEpLen : 96.8
# Train_AverageReturn : 104.9000015258789
# Train_StdReturn : 23.543363571166992
# Train_MaxReturn : 155.0
# Train_MinReturn : 71.0
# Train_AverageEpLen : 104.9
# Actor Loss : 47618.046875
# Train_EnvstepsSoFar : 89345
# TimeSinceStart : 57.82792592048645
# Done logging...
#
#
#
# ********** Iteration 86 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 93.80000305175781
# Eval_StdReturn : 14.958609580993652
# Eval_MaxReturn : 119.0
# Eval_MinReturn : 81.0
# Eval_AverageEpLen : 93.8
# Train_AverageReturn : 91.41666412353516
# Train_StdReturn : 28.373868942260742
# Train_MaxReturn : 165.0
# Train_MinReturn : 62.0
# Train_AverageEpLen : 91.41666666666667
# Actor Loss : 46097.859375
# Train_EnvstepsSoFar : 90442
# TimeSinceStart : 58.38636517524719
# Done logging...
#
#
#
# ********** Iteration 87 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 114.0
# Eval_StdReturn : 29.605743408203125
# Eval_MaxReturn : 157.0
# Eval_MinReturn : 86.0
# Eval_AverageEpLen : 114.0
# Train_AverageReturn : 105.90908813476562
# Train_StdReturn : 29.407651901245117
# Train_MaxReturn : 180.0
# Train_MinReturn : 64.0
# Train_AverageEpLen : 105.9090909090909
# Actor Loss : 53936.63671875
# Train_EnvstepsSoFar : 91607
# TimeSinceStart : 59.638094425201416
# Done logging...
#
#
#
# ********** Iteration 88 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 200.0
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 101.0
# Train_StdReturn : 30.33479881286621
# Train_MaxReturn : 180.0
# Train_MinReturn : 72.0
# Train_AverageEpLen : 101.0
# Actor Loss : 47183.62890625
# Train_EnvstepsSoFar : 92617
# TimeSinceStart : 60.44954586029053
# Done logging...
#
#
#
# ********** Iteration 89 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 101.80000305175781
# Eval_StdReturn : 25.230140686035156
# Eval_MaxReturn : 147.0
# Eval_MinReturn : 81.0
# Eval_AverageEpLen : 101.8
# Train_AverageReturn : 102.81818389892578
# Train_StdReturn : 36.75426483154297
# Train_MaxReturn : 194.0
# Train_MinReturn : 71.0
# Train_AverageEpLen : 102.81818181818181
# Actor Loss : 48142.78125
# Train_EnvstepsSoFar : 93748
# TimeSinceStart : 61.014118909835815
# Done logging...
#
#
#
# ********** Iteration 90 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 114.0
# Eval_StdReturn : 27.02776336669922
# Eval_MaxReturn : 141.0
# Eval_MinReturn : 70.0
# Eval_AverageEpLen : 114.0
# Train_AverageReturn : 105.9000015258789
# Train_StdReturn : 29.797483444213867
# Train_MaxReturn : 165.0
# Train_MinReturn : 67.0
# Train_AverageEpLen : 105.9
# Actor Loss : 46821.1328125
# Train_EnvstepsSoFar : 94807
# TimeSinceStart : 61.839301109313965
# Done logging...
#
#
#
# ********** Iteration 91 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 106.5
# Eval_StdReturn : 32.260658264160156
# Eval_MaxReturn : 162.0
# Eval_MinReturn : 82.0
# Eval_AverageEpLen : 106.5
# Train_AverageReturn : 111.77777862548828
# Train_StdReturn : 30.11746597290039
# Train_MaxReturn : 144.0
# Train_MinReturn : 62.0
# Train_AverageEpLen : 111.77777777777777
# Actor Loss : 45597.578125
# Train_EnvstepsSoFar : 95813
# TimeSinceStart : 62.820966720581055
# Done logging...
#
#
#
# ********** Iteration 92 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 99.4000015258789
# Eval_StdReturn : 22.791227340698242
# Eval_MaxReturn : 138.0
# Eval_MinReturn : 79.0
# Eval_AverageEpLen : 99.4
# Train_AverageReturn : 105.80000305175781
# Train_StdReturn : 43.120296478271484
# Train_MaxReturn : 200.0
# Train_MinReturn : 63.0
# Train_AverageEpLen : 105.8
# Actor Loss : 48351.65234375
# Train_EnvstepsSoFar : 96871
# TimeSinceStart : 63.39475727081299
# Done logging...
#
#
#
# ********** Iteration 93 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 111.0
# Eval_StdReturn : 21.118711471557617
# Eval_MaxReturn : 147.0
# Eval_MinReturn : 93.0
# Eval_AverageEpLen : 111.0
# Train_AverageReturn : 133.75
# Train_StdReturn : 45.39204406738281
# Train_MaxReturn : 200.0
# Train_MinReturn : 68.0
# Train_AverageEpLen : 133.75
# Actor Loss : 60690.953125
# Train_EnvstepsSoFar : 97941
# TimeSinceStart : 64.07272744178772
# Done logging...
#
#
#
# ********** Iteration 94 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 145.0
# Eval_StdReturn : 42.33989334106445
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 97.0
# Eval_AverageEpLen : 145.0
# Train_AverageReturn : 104.80000305175781
# Train_StdReturn : 21.632383346557617
# Train_MaxReturn : 139.0
# Train_MinReturn : 75.0
# Train_AverageEpLen : 104.8
# Actor Loss : 41775.515625
# Train_EnvstepsSoFar : 98989
# TimeSinceStart : 64.6985354423523
# Done logging...
#
#
#
# ********** Iteration 95 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 114.25
# Eval_StdReturn : 49.58011245727539
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 83.0
# Eval_AverageEpLen : 114.25
# Train_AverageReturn : 126.75
# Train_StdReturn : 41.42689514160156
# Train_MaxReturn : 200.0
# Train_MinReturn : 76.0
# Train_AverageEpLen : 126.75
# Actor Loss : 52207.26953125
# Train_EnvstepsSoFar : 100003
# TimeSinceStart : 65.45186042785645
# Done logging...
#
#
#
# ********** Iteration 96 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 110.5
# Eval_StdReturn : 31.7844295501709
# Eval_MaxReturn : 149.0
# Eval_MinReturn : 73.0
# Eval_AverageEpLen : 110.5
# Train_AverageReturn : 109.69999694824219
# Train_StdReturn : 37.23720932006836
# Train_MaxReturn : 175.0
# Train_MinReturn : 71.0
# Train_AverageEpLen : 109.7
# Actor Loss : 46877.30078125
# Train_EnvstepsSoFar : 101100
# TimeSinceStart : 66.85342216491699
# Done logging...
#
#
#
# ********** Iteration 97 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 105.25
# Eval_StdReturn : 23.16651725769043
# Eval_MaxReturn : 137.0
# Eval_MinReturn : 72.0
# Eval_AverageEpLen : 105.25
# Train_AverageReturn : 112.66666412353516
# Train_StdReturn : 42.78888702392578
# Train_MaxReturn : 182.0
# Train_MinReturn : 65.0
# Train_AverageEpLen : 112.66666666666667
# Actor Loss : 50361.9140625
# Train_EnvstepsSoFar : 102114
# TimeSinceStart : 67.85262060165405
# Done logging...
#
#
#
# ********** Iteration 98 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 105.19999694824219
# Eval_StdReturn : 32.04621505737305
# Eval_MaxReturn : 152.0
# Eval_MinReturn : 55.0
# Eval_AverageEpLen : 105.2
# Train_AverageReturn : 92.16666412353516
# Train_StdReturn : 22.589942932128906
# Train_MaxReturn : 154.0
# Train_MinReturn : 65.0
# Train_AverageEpLen : 92.16666666666667
# Actor Loss : 40021.25
# Train_EnvstepsSoFar : 103220
# TimeSinceStart : 69.39822268486023
# Done logging...
#
#
#
# ********** Iteration 99 ************
#
# Collecting data for eval...
# Eval_AverageReturn : 109.75
# Eval_StdReturn : 54.53152847290039
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 61.0
# Eval_AverageEpLen : 109.75
# Train_AverageReturn : 113.66666412353516
# Train_StdReturn : 38.39849853515625
# Train_MaxReturn : 200.0
# Train_MinReturn : 70.0
# Train_AverageEpLen : 113.66666666666667
# Actor Loss : 46136.2890625
# Train_EnvstepsSoFar : 104243
# TimeSinceStart : 70.2428457736969
# Done logging...

# %%
# !python cs285/scripts/run_hw2.py --env_name CartPole-v0 -n 100 -b 1000 -rtg --exp_name cartpole_rtg
# Out:
# python: can't open file 'c:\Users\Matthias\Documents\GitHub\homework_fall2023\hw2\cs285\cs285\scripts\run_hw2.py': [Errno 2] No such file or directory

# %%
# !python cs285/scripts/run_hw2.py --env_name CartPole-v0 -n 100 -b 1000 -rtg --exp_name cartpole_rtg

# %%
# !python cs285/scripts/run_hw2.py --env_name CartPole-v0 -n 100 -b 1000 -na --exp_name cartpole_na

# %%
# !python cs285/scripts/run_hw2.py --env_name CartPole-v0 -n 100 -b 1000 -rtg -na --exp_name cartpole_rtg_na

# %%
# !python cs285/scripts/run_hw2.py --env_name CartPole-v0 -n 100 -b 4000 --exp_name cartpole_lb

# %%
# !python cs285/scripts/run_hw2.py --env_name CartPole-v0 -n 100 -b 4000 -rtg --exp_name cartpole_lb_rtg

# %%
# !python cs285/scripts/run_hw2.py --env_name CartPole-v0 -n 100 -b 4000 -na --exp_name cartpole_lb_na

# %%
# !python cs285/scripts/run_hw2.py --env_name CartPole-v0 -n 100 -b 4000 -rtg -na --exp_name cartpole_lb_rtg_na
